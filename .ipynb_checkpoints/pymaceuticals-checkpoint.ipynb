# %% [markdown]
# # Jason's Pymaceuticals
# ---
#
# ### Analysis
# - It seems as though the Capomulin and the Ramicane are the two treatments that show promise in survival rate, metastic response, and tumor response.
# -

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "Instructions/Pymaceuticals/data/mouse_drug_data.csv"
clinical_trial_data_to_load = "Instructions/Pymaceuticals/data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_df = pd.read_csv(mouse_drug_data_to_load)
ct_df = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
full_df = pd.merge(mouse_df, ct_df, how='left', on='Mouse ID')

# Display the data table for preview
full_df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
jac = full_df.drop(['Metastatic Sites', 'Mouse ID'], axis=1)

mean_vol_0 = jac.groupby(['Drug','Timepoint'])
mean_vol = mean_vol_0.mean()
mean_vol
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
# ...                                 ...
# Zoniferol 25                  55.432935
#           30                  57.713531
#           35                  60.089372
#           40                  62.916692
#           45                  65.960888
#
# [100 rows x 1 columns]

# %%
# Convert to DataFrame
mv_df = mean_vol.reset_index()

# Preview DataFrame
mv_df.head()

mv_dff = mv_df.pivot(index='Timepoint', columns='Drug')

mv_dff.columns = mv_dff.columns.droplevel(0)
mv_dff

mv_col = mv_dff.columns

mv_dff
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
jac1 = full_df.drop(['Metastatic Sites', 'Mouse ID'], axis=1)

std_vol_0 = jac1.groupby(['Drug','Timepoint'])
std_vol = std_vol_0.sem()

# Convert to DataFrame
sev_df = std_vol.reset_index()

# Preview DataFrame
sev_df
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
sev_dff = sev_df.pivot(index='Timepoint', columns='Drug')
sev_dff.columns = sev_dff.columns.droplevel(0)
sev_dff
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
columns = sev_dff.columns

# %%
# ax.errorbar(sev_dff.index, mv_dff['Capomulin'], yerr=sev_dff['Capomulin'], fmt="o", color="b",
#             alpha=0.5, label="Capomulin")
# ax.errorbar(sev_dff.index, mv_dff['Ceftamin'], yerr=sev_dff['Ceftamin'], fmt="o", color="r",
#             alpha=0.5, label="Ceftamin")

# ax.set_xlim(-0.5, len(means))

# %%
# Generate the Plot (with Error Bars)
# Plot sample means with error bars
def volume_plot():
    fig, ax = plt.subplots()
    for x in columns:
        ax.errorbar(sev_dff.index, mv_dff[x], yerr=sev_dff[x], fmt="o", alpha=0.5, label=x)

    ax.set_xlabel("Timepoint")
    ax.set_ylabel("Mean Volume of Tumor (mm3)")

    plt.legend(loc=2, fontsize="small", prop={'size': 7}, fancybox=False)

    plt.savefig("Tumor Response Scatter")
    plt.show()

volume_plot()

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
jac = full_df.drop(['Tumor Volume (mm3)', 'Mouse ID'], axis=1)

mtst_gp = jac.groupby(['Drug','Timepoint'])
mtst_mean = mtst_gp.mean()
mtst_mean

# Convert to DataFrame
mtst_df = mtst_mean.reset_index()

# Preview DataFrame
mtst_df = mtst_df.pivot(index='Timepoint', columns='Drug')
mtst_df.columns = mtst_df.columns.droplevel(0)
mtst_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (Accounting for percentages)

def survival_plot():
    fig, ax = plt.subplots()
    for x in columns:
        ax.plot(mtst_df.index, mtst_df[x])
#     ax.scatter(moco_dff.index, moco_dff['Capomulin'])
#     ax.scatter(moco_dff.index, moco_dff['Ceftamin'])

    ax.set_xlim(-0.5, 48)
    ax.set_xlabel("Timepoint")
    ax.set_ylabel("Survival Rate")

    plt.legend(labels=columns, loc="best", fontsize="small", fancybox=True)

    plt.savefig("Survival Scatter")
    plt.show()
    
survival_plot()

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
mid = full_df[["Mouse ID", "Timepoint", "Drug"]]
mouse_count = mid.groupby(['Drug', 'Timepoint']).count()
# Convert to DataFrame

# Preview DataFrame
mouse_count.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
promoco_df = mouse_count.reset_index()
promoco_df
# Out:
#          Drug  Timepoint  Mouse ID
# 0   Capomulin          0        25
# 1   Capomulin          5        25
# 2   Capomulin         10        25
# 3   Capomulin         15        24
# 4   Capomulin         20        23
# ..        ...        ...       ...
# 95  Zoniferol         25        16
# 96  Zoniferol         30        15
# 97  Zoniferol         35        14
# 98  Zoniferol         40        14
# 99  Zoniferol         45        14
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
moco_df = promoco_df.pivot(index='Timepoint', columns='Drug')
moco_df.columns = moco_df.columns.droplevel(0)

# Preview the Data Frame
moco_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
columns = ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo',
       'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol']
columns
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
# # create function that performs the percent calculation across all coulumns
def survivalrate():
    for x in columns:
        moco_df[x] = moco_df[x]/moco_df[x][0]
survivalrate()
perct_moco = moco_df

# %%
perct_moco = perct_moco.round(2)
perct_moco
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0               1.00      1.00       1.00      1.00      1.00     1.00
# 5               1.00      0.84       1.00      0.92      0.92     0.96
# 10              1.00      0.80       0.84      0.88      0.84     0.96
# 15              0.96      0.76       0.84      0.76      0.84     0.80
# 20              0.92      0.72       0.80      0.76      0.80     0.76
# 25              0.88      0.72       0.72      0.76      0.72     0.68
# 30              0.88      0.64       0.68      0.72      0.60     0.60
# 35              0.88      0.56       0.48      0.68      0.60     0.56
# 40              0.84      0.56       0.40      0.60      0.60     0.48
# 45              0.84      0.52       0.36      0.44      0.52     0.44
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0              1.00      1.00      1.00       1.00
# 5              0.96      1.00      0.96       0.96
# ...

# %%
# Generate the Plot (Accounting for percentages)

def survival_plot():
    fig, ax = plt.subplots()
    for x in columns:
        ax.plot(perct_moco.index, perct_moco[x])
#     ax.scatter(moco_dff.index, moco_dff['Capomulin'])
#     ax.scatter(moco_dff.index, moco_dff['Ceftamin'])

    ax.set_xlim(-0.5, 48)
    ax.set_xlabel("Timepoint")
    ax.set_ylabel("Survival Rate")

    plt.legend(labels=columns, loc="best", fontsize="small", fancybox=True)

    plt.savefig("Survival Scatter")
    plt.show()
    
survival_plot()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
